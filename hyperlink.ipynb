# %%
from jobspy import scrape_jobs
import pandas as pd
from IPython.display import display, HTML

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# %%
# example 1 (no hyperlinks, USA)
jobs = scrape_jobs(
    site_name=["indeed", "zip_recruiter", "linkedin"],
    location='USA',
    search_term="software engineer",
    results_wanted=5000,
    hours_old=168,
    linkedin_fetch_description=True

    # use if you want to use a proxy
    # proxy="socks5://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
    #proxy="http://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
    #proxy="https://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
)
jobs.to_excel('example.xlsx', index=False)
#display(jobs)
# Out:
# 2024-10-02 15:58:04,947 - JobSpy - INFO - Indeed search page: 1
# 2024-10-02 15:58:04,969 - JobSpy - INFO - LinkedIn search page: 1
# 2024-10-02 15:58:05,138 - JobSpy - INFO - ZipRecruiter search page: 1
# 2024-10-02 15:58:06,085 - JobSpy - INFO - Indeed search page: 2
# 2024-10-02 15:58:07,218 - JobSpy - INFO - Indeed search page: 3
# 2024-10-02 15:58:08,419 - JobSpy - INFO - Indeed search page: 4
# 2024-10-02 15:58:09,393 - JobSpy - INFO - Indeed search page: 5
# 2024-10-02 15:58:10,742 - JobSpy - INFO - Indeed search page: 6
# 2024-10-02 15:58:11,710 - JobSpy - INFO - ZipRecruiter search page: 2
# 2024-10-02 15:58:11,816 - JobSpy - INFO - Indeed search page: 7
# 2024-10-02 15:58:12,870 - JobSpy - INFO - Indeed search page: 8
# 2024-10-02 15:58:13,939 - JobSpy - INFO - Indeed search page: 9
# 2024-10-02 15:58:14,951 - JobSpy - INFO - Indeed search page: 10
# 2024-10-02 15:58:16,124 - JobSpy - INFO - Indeed search page: 11
# 2024-10-02 15:58:16,874 - JobSpy - INFO - Indeed found no jobs on page: 11
# 2024-10-02 15:58:16,874 - JobSpy - INFO - Indeed finished scraping
# 2024-10-02 15:59:38,480 - JobSpy - INFO - LinkedIn search page: 2
# 2024-10-02 16:02:02,114 - JobSpy - INFO - LinkedIn search page: 3
# 2024-10-02 16:04:15,455 - JobSpy - INFO - LinkedIn search page: 4
# 2024-10-02 16:06:20,615 - JobSpy - INFO - LinkedIn search page: 5
# 2024-10-02 16:07:57,403 - JobSpy - INFO - LinkedIn search page: 6
# 2024-10-02 16:09:52,758 - JobSpy - INFO - LinkedIn search page: 7
# 2024-10-02 16:11:06,307 - JobSpy - INFO - LinkedIn search page: 8
# 2024-10-02 16:12:09,115 - JobSpy - INFO - LinkedIn search page: 9
# 2024-10-02 16:12:39,489 - JobSpy - ERROR - LinkedIn: HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=software+engineer&location=USA&distance=50&pageNum=0&start=339&f_TPR=r604800 (Caused by ResponseError('too many 429 error responses'))
# 2024-10-02 16:12:39,493 - JobSpy - INFO - Linkedin finished scraping
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # example 1 (no hyperlinks, USA)
# ----> 2 jobs = scrape_jobs(
#       3     site_name=["indeed", "zip_recruiter", "linkedin"],
#       4     location='USA',
#       5     search_term="software engineer",
#       6     results_wanted=5000,
#       7     hours_old=168,
#       8     linkedin_fetch_description=True
#       9
#      10     # use if you want to use a proxy
#      11     # proxy="socks5://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
#      12     #proxy="http://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
#      13     #proxy="https://jobspy:5a4vpWtj4EeJ2hoYzk@us.smartproxy.com:10001",
#      14 )
#      15 jobs.to_excel('example.xlsx', index=False)
#      16 #display(jobs)
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\__init__.py:119, in scrape_jobs(site_name, search_term, location, distance, is_remote, job_type, easy_apply, results_wanted, country_indeed, hyperlinks, proxies, description_format, linkedin_fetch_description, linkedin_company_ids, offset, hours_old, enforce_annual_salary, verbose, **kwargs)
#     114     future_to_site = {
#     115         executor.submit(worker, site): site for site in scraper_input.site_type
#     116     }
#     118     for future in as_completed(future_to_site):
# --> 119         site_value, scraped_data = future.result()
#     120         site_to_jobs_dict[site_value] = scraped_data
#     122 def convert_to_annual(job_data: dict):
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\__init__.py:110, in scrape_jobs.<locals>.worker(site)
#     109 def worker(site):
# --> 110     site_val, scraped_info = scrape_site(site)
#     111     return site_val, scraped_info
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\__init__.py:101, in scrape_jobs.<locals>.scrape_site(site)
#      99 scraper_class = SCRAPER_MAPPING[site]
#     100 scraper = scraper_class(proxies=proxies)
# --> 101 scraped_data: JobResponse = scraper.scrape(scraper_input)
#     102 cap_name = site.value.capitalize()
#     103 site_name = "ZipRecruiter" if cap_name == "Zip_recruiter" else cap_name
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\scrapers\ziprecruiter\__init__.py:75, in ZipRecruiterScraper.scrape(self, scraper_input)
#      73     time.sleep(self.delay)
#      74 logger.info(f"ZipRecruiter search page: {page}")
# ---> 75 jobs_on_page, continue_token = self._find_jobs_in_page(
#      76     scraper_input, continue_token
#      77 )
#      78 if jobs_on_page:
#      79     job_list.extend(jobs_on_page)
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\scrapers\ziprecruiter\__init__.py:124, in ZipRecruiterScraper._find_jobs_in_page(self, scraper_input, continue_token)
#     121 with ThreadPoolExecutor(max_workers=self.jobs_per_page) as executor:
#     122     job_results = [executor.submit(self._process_job, job) for job in jobs_list]
# --> 124 job_list = list(filter(None, (result.result() for result in job_results)))
#     125 return job_list, next_continue_token
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\scrapers\ziprecruiter\__init__.py:124, in <genexpr>(.0)
#     121 with ThreadPoolExecutor(max_workers=self.jobs_per_page) as executor:
#     122     job_results = [executor.submit(self._process_job, job) for job in jobs_list]
# --> 124 job_list = list(filter(None, (result.result() for result in job_results)))
#     125 return job_list, next_continue_token
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\scrapers\ziprecruiter\__init__.py:160, in ZipRecruiterScraper._process_job(self, job)
#     158 comp_max = int(job["compensation_max"]) if "compensation_max" in job else None
#     159 comp_currency = job.get("compensation_currency")
# --> 160 description_full, job_url_direct = self._get_descr(job_url)
#     162 return JobPost(
#     163     id=str(job["listing_key"]),
#     164     title=title,
#    (...)
#     179     listing_type=listing_type,
#     180 )
#
# File c:\Users\kvern\AppData\Local\Programs\Python\Python312\Lib\site-packages\jobspy\scrapers\ziprecruiter\__init__.py:203, in ZipRecruiterScraper._get_descr(self, job_url)
#     201 if script_tag:
#     202     job_json = json.loads(script_tag.string)
# --> 203     job_url_val = job_json["model"].get("saveJobURL", "")
#     204     m = re.search(r"job_url=(.+)", job_url_val)
#     205     if m:
#
# KeyError: 'model'
